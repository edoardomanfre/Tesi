# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import plot,show,hist,figure,title

# %%
filename1 = 'Week_1.xlsx'
filename2 = 'Week_2.xlsx'
filename3 = 'Week_3.xlsx'
filename4 = 'Week_4.xlsx'
filename5 = 'Week_5.xlsx'
filename6 = 'Week_6.xlsx'
filename7 = 'Week_7.xlsx'
filename8 = 'Week_8.xlsx'
filename9 = 'Week_9.xlsx'
filename10 = 'Week_10.xlsx'
filename11 = 'Week_11.xlsx'
filename12 = 'Week_12.xlsx'
filename13 = 'Week_13.xlsx'
filename14 = 'Week_14.xlsx'
filename15 = 'Week_15.xlsx'
filename16 = 'Week_16.xlsx'
filename17 = 'Week_17.xlsx'
filename18 = 'Week_18.xlsx'
filename19 = 'Week_19.xlsx'
filename20 = 'Week_20.xlsx'
filename21 = 'Week_21.xlsx'
filename22 = 'Week_22.xlsx'
filename23 = 'Week_23.xlsx'
filename24 = 'Week_24.xlsx'
filename25 = 'Week_25.xlsx'
filename26 = 'Week_26.xlsx'
filename27 = 'Week_27.xlsx'
filename28 = 'Week_28.xlsx'
filename29 = 'Week_29.xlsx'
filename30 = 'Week_30.xlsx'
filename31 = 'Week_31.xlsx'
filename32 = 'Week_32.xlsx'
filename33 = 'Week_33.xlsx'
filename34 = 'Week_34.xlsx'
filename35 = 'Week_35.xlsx'
filename36 = 'Week_36.xlsx'
filename37 = 'Week_37.xlsx'
filename38 = 'Week_38.xlsx'
filename39 = 'Week_39.xlsx'
filename40 = 'Week_40.xlsx'
filename41 = 'Week_41.xlsx'
filename42 = 'Week_42.xlsx'
filename43 = 'Week_43.xlsx'
filename44 = 'Week_44.xlsx'
filename45 = 'Week_45.xlsx'
filename46 = 'Week_46.xlsx'
filename47 = 'Week_47.xlsx'
filename48 = 'Week_48.xlsx'
filename49 = 'Week_49.xlsx'
filename50 = 'Week_50.xlsx'
filename51 = 'Week_51.xlsx'
filename52 = 'Week_52.xlsx'

# %%
Data1 = pd.read_excel(filename1, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data2 = pd.read_excel(filename2, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data3 = pd.read_excel(filename3, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data4 = pd.read_excel(filename4, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data5 = pd.read_excel(filename5, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data6 = pd.read_excel(filename6, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data7 = pd.read_excel(filename7, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data8 = pd.read_excel(filename8, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data9 = pd.read_excel(filename9, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data10 = pd.read_excel(filename10, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data11 = pd.read_excel(filename11, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data12 = pd.read_excel(filename12, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data13 = pd.read_excel(filename13, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data14 = pd.read_excel(filename14, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data15 = pd.read_excel(filename15, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data16 = pd.read_excel(filename16, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data17 = pd.read_excel(filename17, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data18 = pd.read_excel(filename18, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data19 = pd.read_excel(filename19, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data20 = pd.read_excel(filename20, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data21 = pd.read_excel(filename21, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data22 = pd.read_excel(filename22, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data23 = pd.read_excel(filename23, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data24 = pd.read_excel(filename24, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data25 = pd.read_excel(filename25, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data26 = pd.read_excel(filename26, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data27 = pd.read_excel(filename27, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data28 = pd.read_excel(filename28, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data29 = pd.read_excel(filename29, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data30 = pd.read_excel(filename30, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data31 = pd.read_excel(filename31, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data32 = pd.read_excel(filename32, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data33 = pd.read_excel(filename33, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data34 = pd.read_excel(filename34, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data35 = pd.read_excel(filename35, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data36 = pd.read_excel(filename36, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data37 = pd.read_excel(filename37, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data38 = pd.read_excel(filename38, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data39 = pd.read_excel(filename39, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data40 = pd.read_excel(filename40, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data41 = pd.read_excel(filename41, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data42 = pd.read_excel(filename42, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data43 = pd.read_excel(filename43, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data44 = pd.read_excel(filename44, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data45 = pd.read_excel(filename45, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data46 = pd.read_excel(filename46, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data47 = pd.read_excel(filename47, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data48 = pd.read_excel(filename48, sheet_name = 'upper_volume_Mm3', usecols= [1]) 
Data49 = pd.read_excel(filename49, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data50 = pd.read_excel(filename50, sheet_name = 'upper_volume_Mm3', usecols = [1]) 
Data51 = pd.read_excel(filename51, sheet_name = 'upper_volume_Mm3', usecols= [1])
Data52 = pd.read_excel(filename52, sheet_name = 'upper_volume_Mm3', usecols= [1])

# %%
df_1 = pd.DataFrame(Data1)
df_2 = pd.DataFrame(Data2)
df_3 = pd.DataFrame(Data3)
df_4 = pd.DataFrame(Data4)
df_5 = pd.DataFrame(Data5)
df_6 = pd.DataFrame(Data6)
df_7 = pd.DataFrame(Data7)
df_8 = pd.DataFrame(Data8)
df_9 = pd.DataFrame(Data9)
df_10 = pd.DataFrame(Data10)
df_11 = pd.DataFrame(Data11)
df_12 = pd.DataFrame(Data12)
df_13 = pd.DataFrame(Data13)
df_14 = pd.DataFrame(Data14)
df_15 = pd.DataFrame(Data15)
df_16 = pd.DataFrame(Data16)
df_17 = pd.DataFrame(Data17)
df_18 = pd.DataFrame(Data18)
df_19 = pd.DataFrame(Data19)
df_20 = pd.DataFrame(Data20)
df_21 = pd.DataFrame(Data21)
df_22 = pd.DataFrame(Data22)
df_23 = pd.DataFrame(Data23)
df_24 = pd.DataFrame(Data24)
df_25 = pd.DataFrame(Data25)
df_26 = pd.DataFrame(Data26)
df_27 = pd.DataFrame(Data27)
df_28 = pd.DataFrame(Data28)
df_29 = pd.DataFrame(Data29)
df_30 = pd.DataFrame(Data30)
df_31 = pd.DataFrame(Data31)
df_32 = pd.DataFrame(Data32)
df_33 = pd.DataFrame(Data33)
df_34 = pd.DataFrame(Data34)
df_35 = pd.DataFrame(Data35)
df_36 = pd.DataFrame(Data36)
df_37 = pd.DataFrame(Data37)
df_38 = pd.DataFrame(Data38)
df_39 = pd.DataFrame(Data39)
df_40 = pd.DataFrame(Data40)
df_41 = pd.DataFrame(Data41)
df_42 = pd.DataFrame(Data42)
df_43 = pd.DataFrame(Data43)
df_44 = pd.DataFrame(Data44)
df_45 = pd.DataFrame(Data45)
df_46 = pd.DataFrame(Data46)
df_47 = pd.DataFrame(Data47)
df_48 = pd.DataFrame(Data48)
df_49 = pd.DataFrame(Data49)
df_50 = pd.DataFrame(Data50)
df_51 = pd.DataFrame(Data51)
df_52 = pd.DataFrame(Data52)

# %%
df = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,
               df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,df_30,df_31,
               df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,df_40,df_41,df_42,df_43,df_44,df_45,df_46,
                df_47,df_48,df_49,df_50,df_51,df_52])
df = df.reset_index(drop=True)

# %%
display(df)
# Out:
#         Scen_2
# 0     0.014120
# 1     0.107396
# 2     0.200681
# 3     0.293945
# 4     0.308064
# ...        ...
# 2907  8.741696
# 2908  8.616907
# 2909  8.492119
# 2910  8.367331
# 2911  8.242543
#
# [2912 rows x 1 columns]

# %%
plt.plot(df['Scen_2'])
